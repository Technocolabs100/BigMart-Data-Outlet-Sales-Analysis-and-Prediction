# %%
#DATA EXPLORATION
import pandas as pd
import matplotlib.pyplot as plt

# %%
# train and test data
train_data = pd.read_csv("C:\\Users\\psrmu\\Downloads\\9961_14084_bundle_archive\\Train.csv")
test_data = pd.read_csv("C:\\Users\\psrmu\\Downloads\\9961_14084_bundle_archive\\Test.csv")

# %%
print("Train Dataset Info:")
print(train_data.info())
# Out:
# Train Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# ...

# %%
print("\nTest Dataset Info:")
print(test_data.info())
# Out:
# Test Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB
# None

# %%
print("\nFirst few rows of Train Dataset:")
print(train_data.head())
# Out:
# First few rows of Train Dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print("\nFirst few rows of Test Dataset:")
print(test_data.head())
# Out:
# First few rows of Test Dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
print("\nSummary Statistics of Numerical Features in Train Dataset:")
print(train_data.describe())
# Out:
# Summary Statistics of Numerical Features in Train Dataset:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# ...

# %%
print("\nSummary Statistics of Numerical Features in Test Dataset:")
print(test_data.describe())
# Out:
# Summary Statistics of Numerical Features in Test Dataset:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
# Plotting histograms with train dataset
train_data.hist(figsize=(12, 10))
plt.suptitle("Histograms of Numerical Features in Train Dataset")
plt.show()

# %%
# Plotting histograms with test dataset
test_data.hist(figsize=(12, 10))
plt.suptitle("Histograms of Numerical Features in Test Dataset")
plt.show()

# %%
numeric_train_data = train_data.select_dtypes(include=['float64', 'int64'])

# correlation matrix
corr_matrix_train = numeric_train_data.corr()
plt.figure(figsize=(10, 8))
plt.title("Correlation Matrix - Train Dataset")
plt.matshow(corr_matrix_train, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(corr_matrix_train.columns)), corr_matrix_train.columns, rotation='vertical')
plt.yticks(range(len(corr_matrix_train.columns)), corr_matrix_train.columns)
plt.show()

# %%
numeric_test_data = test_data.select_dtypes(include=['float64', 'int64'])

# Plotting correlation matrix
corr_matrix_test = numeric_test_data.corr()
plt.figure(figsize=(10, 8))
plt.title("Correlation Matrix - Test Dataset")
plt.matshow(corr_matrix_test, cmap='coolwarm', fignum=2)
plt.colorbar()
plt.xticks(range(len(corr_matrix_test.columns)), corr_matrix_test.columns, rotation='vertical')
plt.yticks(range(len(corr_matrix_test.columns)), corr_matrix_test.columns)
plt.show()

# %%
#DATA CLEANING
import pandas as pd

# %%
# Load train and test datasets
train_data = pd.read_csv("C:\\Users\\psrmu\\Downloads\\9961_14084_bundle_archive\\Train.csv")
test_data = pd.read_csv("C:\\Users\\psrmu\\Downloads\\9961_14084_bundle_archive\\Test.csv")

# %%
# Display the first few rows of the train dataset
print("Train dataset:")
print(train_data.head())
# Out:
# Train dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Display the first few rows of the test dataset
print("\nTest dataset:")
print(test_data.head())
# Out:
# Test dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# Check for missing values in train dataset
print("\nMissing values in train dataset:")
print(train_data.isnull().sum())
# Out:
# Missing values in train dataset:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Check for missing values in test dataset
print("\nMissing values in test dataset:")
print(test_data.isnull().sum())
# Out:
# Missing values in test dataset:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
# Remove duplicates in train dataset
train_data.drop_duplicates(inplace=True)

# %%
# Remove duplicates in test dataset
test_data.drop_duplicates(inplace=True)

# %%
train_data.to_csv("cleaned_train.csv", index=False)
test_data.to_csv("cleaned_test.csv", index=False)
print("\nData cleaning completed and cleaned datasets saved.")
# Out:
# Data cleaning completed and cleaned datasets saved.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Load cleaned train and test datasets
cleaned_train_data = pd.read_csv("cleaned_train.csv")
cleaned_test_data = pd.read_csv("cleaned_test.csv")

# %%
# Display the column names of cleaned train and test datasets
print("Cleaned Train dataset columns:")
print(cleaned_train_data.columns)
# Out:
# Cleaned Train dataset columns:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
print("\nCleaned Test dataset columns:")
print(cleaned_test_data.columns)
# Out:
# Cleaned Test dataset columns:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
# Example 1: Label Encoding
label_encoder = LabelEncoder()

# %%
# Check if 'Gender' and 'City' columns are present in the datasets
if 'Gender' in cleaned_train_data.columns and 'City' in cleaned_train_data.columns:
    # Encode 'Gender' and 'City' columns in cleaned train dataset
    cleaned_train_data['Gender_encoded'] = label_encoder.fit_transform(cleaned_train_data['Gender'])
    cleaned_train_data['City_encoded'] = label_encoder.fit_transform(cleaned_train_data['City'])

# %%
# Check if 'Gender' and 'City' columns are present in the test dataset
if 'Gender' in cleaned_test_data.columns and 'City' in cleaned_test_data.columns:
    # Encode 'Gender' and 'City' columns in cleaned test dataset
    cleaned_test_data['Gender_encoded'] = label_encoder.transform(cleaned_test_data['Gender'])
    cleaned_test_data['City_encoded'] = label_encoder.transform(cleaned_test_data['City'])

# %%
# Display the encoded datasets
print("\nCleaned Train dataset after label encoding:")
print(cleaned_train_data.head())
# Out:
# Cleaned Train dataset after label encoding:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print("\nCleaned Test dataset after label encoding:")
print(cleaned_test_data.head())
# Out:
# Cleaned Test dataset after label encoding:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
# ...

# %%
#DATA ENCODING
import pandas as pd

# %%
# Load cleaned train dataset
cleaned_train_data = pd.read_csv("cleaned_train.csv")

# %%
# Display the column names of the cleaned train dataset
print("Column names of cleaned train dataset:")
print(cleaned_train_data.columns)
# Out:
# Column names of cleaned train dataset:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
import pandas as pd

# %%
# Load cleaned train dataset
cleaned_train_data = pd.read_csv("cleaned_train.csv")

# %%
# Display the first few rows of the cleaned train dataset
print("Cleaned Train dataset:")
print(cleaned_train_data.head())
# Out:
# Cleaned Train dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Specify the correct target variable
target_variable = 'Item_Outlet_Sales'

# Assign the target variable to the labels
labels = cleaned_train_data[target_variable]

# Display the labels
print("\nLabels:")
print(labels.head())
# Out:
# Labels:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
# Optionally, you can remove the target variable from the features
features = cleaned_train_data.drop(columns=[target_variable])

# Display the features
print("\nFeatures:")
print(features.head())
# Out:
# Features:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#DATA LABELING
import pandas as pd

# Load cleaned train dataset
cleaned_train_data = pd.read_csv("cleaned_train.csv")

# Display the column names of the cleaned train dataset
print("Column names of cleaned train dataset:")
print(cleaned_train_data.columns)
# Out:
# Column names of cleaned train dataset:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
import pandas as pd

# Load cleaned train dataset
cleaned_train_data = pd.read_csv("cleaned_train.csv")

# %%
# Display the first few rows of the cleaned train dataset
print("Cleaned Train dataset:")
print(cleaned_train_data.head())
# Out:
# Cleaned Train dataset:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Specify the correct target variable
target_variable = 'Item_Outlet_Sales'

# Assign the target variable to the labels
labels = cleaned_train_data[target_variable]

# Display the labels
print("\nLabels:")
print(labels.head())
# Out:
# Labels:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
# Optionally, you can remove the target variable from the features
features = cleaned_train_data.drop(columns=[target_variable])

# Display the features
print("\nFeatures:")
print(features.head())
# Out:
# Features:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...
